# %% [markdown]
# # Timeseries classification from scratch
#
# **Author:** [hfawaz](https://github.com/hfawaz/)<br>
# **Date created:** 2020/07/21<br>
# **Last modified:** 2023/11/10<br>
# **Description:** Training a timeseries classifier from scratch on the FordA dataset from the UCR/UEA archive.

# %% [markdown]
# ## Introduction
#
# This example shows how to do timeseries classification from scratch, starting from raw
# CSV timeseries files on disk. We demonstrate the workflow on the FordA dataset from the
# [UCR/UEA archive](https://www.cs.ucr.edu/%7Eeamonn/time_series_data_2018/).

# %% [markdown]
# ## Setup

# %%
import keras
import numpy as np
import matplotlib.pyplot as plt
# Out:
# WARNING:tensorflow:From c:\AppData\.devhome\conda\envs\py311tf216\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ## Load the data: the FordA dataset
#
# ### Dataset description
#
# The dataset we are using here is called FordA.
# The data comes from the UCR archive.
# The dataset contains 3601 training instances and another 1320 testing instances.
# Each timeseries corresponds to a measurement of engine noise captured by a motor sensor.
# For this task, the goal is to automatically detect the presence of a specific issue with
# the engine. The problem is a balanced binary classification task. The full description of
# this dataset can be found [here](http://www.j-wichard.de/publications/FordPaper.pdf).
#
# ### Read the TSV data
#
# We will use the `FordA_TRAIN` file for training and the
# `FordA_TEST` file for testing. The simplicity of this dataset
# allows us to demonstrate effectively how to use ConvNets for timeseries classification.
# In this file, the first column corresponds to the label.

# %%
def readucr(filename):
    data = np.loadtxt(filename, delimiter="\t")
    y = data[:, 0]
    x = data[:, 1:]
    return x, y.astype(int)


root_url = "https://raw.githubusercontent.com/hfawaz/cd-diagram/master/FordA/"

x_train, y_train = readucr(root_url + "FordA_TRAIN.tsv")
x_test, y_test = readucr(root_url + "FordA_TEST.tsv")

# %% [markdown]
# ## Visualize the data
#
# Here we visualize one timeseries example for each class in the dataset.

# %%
classes = np.unique(np.concatenate((y_train, y_test), axis=0))

plt.figure()
for c in classes:
    c_x_train = x_train[y_train == c]
    plt.plot(c_x_train[0], label="class " + str(c))
plt.legend(loc="best")
plt.show()
plt.close()

# %% [markdown]
# ## Standardize the data
#
# Our timeseries are already in a single length (500). However, their values are
# usually in various ranges. This is not ideal for a neural network;
# in general we should seek to make the input values normalized.
# For this specific dataset, the data is already z-normalized: each timeseries sample
# has a mean equal to zero and a standard deviation equal to one. This type of
# normalization is very common for timeseries classification problems, see
# [Bagnall et al. (2016)](https://link.springer.com/article/10.1007/s10618-016-0483-9).
#
# Note that the timeseries data used here are univariate, meaning we only have one channel
# per timeseries example.
# We will therefore transform the timeseries into a multivariate one with one channel
# using a simple reshaping via numpy.
# This will allow us to construct a model that is easily applicable to multivariate time
# series.

# %%
x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))

# %% [markdown]
# Finally, in order to use `sparse_categorical_crossentropy`, we will have to count
# the number of classes beforehand.

# %%
num_classes = len(np.unique(y_train))

# %% [markdown]
# Now we shuffle the training set because we will be using the `validation_split` option
# later when training.

# %%
idx = np.random.permutation(len(x_train))
x_train = x_train[idx]
y_train = y_train[idx]

# %% [markdown]
# Standardize the labels to positive integers.
# The expected labels will then be 0 and 1.

# %%
y_train[y_train == -1] = 0
y_test[y_test == -1] = 0

# %% [markdown]
# ## Build a model
#
# We build a Fully Convolutional Neural Network originally proposed in
# [this paper](https://arxiv.org/abs/1611.06455).
# The implementation is based on the TF 2 version provided
# [here](https://github.com/hfawaz/dl-4-tsc/).
# The following hyperparameters (kernel_size, filters, the usage of BatchNorm) were found
# via random search using [KerasTuner](https://github.com/keras-team/keras-tuner).

# %%
def make_model(input_shape):
    input_layer = keras.layers.Input(input_shape)

    conv1 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(input_layer)
    conv1 = keras.layers.BatchNormalization()(conv1)
    conv1 = keras.layers.ReLU()(conv1)

    conv2 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv1)
    conv2 = keras.layers.BatchNormalization()(conv2)
    conv2 = keras.layers.ReLU()(conv2)

    conv3 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv2)
    conv3 = keras.layers.BatchNormalization()(conv3)
    conv3 = keras.layers.ReLU()(conv3)

    gap = keras.layers.GlobalAveragePooling1D()(conv3)

    output_layer = keras.layers.Dense(num_classes, activation="softmax")(gap)

    return keras.models.Model(inputs=input_layer, outputs=output_layer)


model = make_model(input_shape=x_train.shape[1:])
keras.utils.plot_model(model, show_shapes=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 23
#      18     output_layer = keras.layers.Dense(num_classes, activation="softmax")(gap)
#      20     return keras.models.Model(inputs=input_layer, outputs=output_layer)
# ---> 23 model = make_model(input_shape=x_train.shape[1:])
#      24 keras.utils.plot_model(model, show_shapes=True)
#
# Cell In[8], line 2, in make_model(input_shape)
#       1 def make_model(input_shape):
# ----> 2     input_layer = keras.layers.Input(input_shape)
#       4     conv1 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(input_layer)
#       5     conv1 = keras.layers.BatchNormalization()(conv1)
#
# File c:\AppData\.devhome\conda\envs\py311tf216\Lib\site-packages\keras\src\utils\traceback_utils.py:70, in error_handler(*args, **kwargs)
#      60 @keras_export("keras.config.is_traceback_filtering_enabled")
#      61 def is_traceback_filtering_enabled():
#      62     """Check if traceback filtering is enabled.
#      63
#      64     Raw Keras tracebacks (also known as stack traces)
#      65     involve many internal frames, which can be
#      66     challenging to read through, while not being actionable for end users.
#      67     By default, Keras filters internal frames in most exceptions that it
#      68     raises, to keep traceback short, readable, and focused on what's
#      69     actionable for you (your own code).
# ---> 70
#      71     See also `keras.config.enable_traceback_filtering()` and
#      72     `keras.config.disable_traceback_filtering()`.
#      73
#      74     If you have previously disabled traceback filtering via
#      75     `keras.config.disable_traceback_filtering()`, you can re-enable it via
#      76     `keras.config.enable_traceback_filtering()`.
#      77
#      78     Returns:
#      79         Boolean, `True` if traceback filtering is enabled,
#      80         and `False` otherwise.
#      81     """
#      82     return global_state.get_global_attribute("traceback_filtering", True)
#
# File c:\AppData\.devhome\conda\envs\py311tf216\Lib\importlib\__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1140, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'keras.src.engine.base_layer_v1'

# %% [markdown]
# ## Train the model

# %%
epochs = 500
batch_size = 32

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model.keras", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["sparse_categorical_accuracy"],
)
history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.2,
    verbose=1,
)
# Out:
# Epoch 1/500
# The history saving thread hit an unexpected error (OperationalError('database is locked')).History will not be written to the database.
# 2024-04-17 20:34:20.602212: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8904
# 2024-04-17 20:34:28.375527: I external/local_xla/xla/service/service.cc:168] XLA service 0x7f9995ea7f80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-04-17 20:34:28.375552: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4070 Ti, Compute Capability 8.9
# 2024-04-17 20:34:28.387852: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1713357268.451636    5449 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 90/90 [==============================] - 25s 8ms/step - loss: 0.5772 - sparse_categorical_accuracy: 0.6896 - val_loss: 0.8858 - val_sparse_categorical_accuracy: 0.4938 - lr: 0.0010
# Epoch 2/500
# 90/90 [==============================] - 9s 99ms/step - loss: 0.4762 - sparse_categorical_accuracy: 0.7684 - val_loss: 1.0497 - val_sparse_categorical_accuracy: 0.4938 - lr: 0.0010
# Epoch 3/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.4344 - sparse_categorical_accuracy: 0.7892 - val_loss: 0.9076 - val_sparse_categorical_accuracy: 0.4938 - lr: 0.0010
# Epoch 4/500
# 90/90 [==============================] - 10s 114ms/step - loss: 0.4308 - sparse_categorical_accuracy: 0.7917 - val_loss: 1.0734 - val_sparse_categorical_accuracy: 0.4938 - lr: 0.0010
# Epoch 5/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.4089 - sparse_categorical_accuracy: 0.7934 - val_loss: 0.9398 - val_sparse_categorical_accuracy: 0.4965 - lr: 0.0010
# Epoch 6/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.4206 - sparse_categorical_accuracy: 0.7872 - val_loss: 0.5267 - val_sparse_categorical_accuracy: 0.7060 - lr: 0.0010
# Epoch 7/500
# 90/90 [==============================] - 8s 92ms/step - loss: 0.3889 - sparse_categorical_accuracy: 0.8073 - val_loss: 0.6681 - val_sparse_categorical_accuracy: 0.6311 - lr: 0.0010
# Epoch 8/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.3915 - sparse_categorical_accuracy: 0.8031 - val_loss: 0.4010 - val_sparse_categorical_accuracy: 0.8141 - lr: 0.0010
# Epoch 9/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.3783 - sparse_categorical_accuracy: 0.8122 - val_loss: 0.3534 - val_sparse_categorical_accuracy: 0.8100 - lr: 0.0010
# Epoch 10/500
# 90/90 [==============================] - 10s 108ms/step - loss: 0.3765 - sparse_categorical_accuracy: 0.8149 - val_loss: 0.3844 - val_sparse_categorical_accuracy: 0.7614 - lr: 0.0010
# Epoch 11/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.3663 - sparse_categorical_accuracy: 0.8337 - val_loss: 0.3867 - val_sparse_categorical_accuracy: 0.7822 - lr: 0.0010
# Epoch 12/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.3548 - sparse_categorical_accuracy: 0.8434 - val_loss: 0.4256 - val_sparse_categorical_accuracy: 0.7850 - lr: 0.0010
# Epoch 13/500
# 90/90 [==============================] - 10s 110ms/step - loss: 0.3626 - sparse_categorical_accuracy: 0.8285 - val_loss: 0.3136 - val_sparse_categorical_accuracy: 0.8363 - lr: 0.0010
# Epoch 14/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.3265 - sparse_categorical_accuracy: 0.8552 - val_loss: 0.3325 - val_sparse_categorical_accuracy: 0.8544 - lr: 0.0010
# Epoch 15/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.3297 - sparse_categorical_accuracy: 0.8486 - val_loss: 0.3606 - val_sparse_categorical_accuracy: 0.8252 - lr: 0.0010
# Epoch 16/500
# 90/90 [==============================] - 9s 105ms/step - loss: 0.3367 - sparse_categorical_accuracy: 0.8524 - val_loss: 1.4438 - val_sparse_categorical_accuracy: 0.5104 - lr: 0.0010
# Epoch 17/500
# 90/90 [==============================] - 0s 5ms/step - loss: 0.3230 - sparse_categorical_accuracy: 0.8542 - val_loss: 0.4278 - val_sparse_categorical_accuracy: 0.7753 - lr: 0.0010
# Epoch 18/500
# 90/90 [==============================] - 10s 117ms/step - loss: 0.3190 - sparse_categorical_accuracy: 0.8635 - val_loss: 0.8286 - val_sparse_categorical_accuracy: 0.5700 - lr: 0.0010
# Epoch 19/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.3098 - sparse_categorical_accuracy: 0
- sparse_categorical_accuracy: 0.9646 - val_loss: 0.1712 - val_sparse_categorical_accuracy: 0.9168 - lr: 0.0010
# Epoch 70/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.1240 - sparse_categorical_accuracy: 0.9573 - val_loss: 0.2553 - val_sparse_categorical_accuracy: 0.8807 - lr: 0.0010
# Epoch 71/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.1167 - sparse_categorical_accuracy: 0.9590 - val_loss: 0.2932 - val_sparse_categorical_accuracy: 0.8627 - lr: 0.0010
# Epoch 72/500
# 90/90 [==============================] - 15s 165ms/step - loss: 0.1239 - sparse_categorical_accuracy: 0.9590 - val_loss: 0.1661 - val_sparse_categorical_accuracy: 0.9445 - lr: 0.0010
# Epoch 73/500
# 90/90 [==============================] - 0s 5ms/step - loss: 0.1236 - sparse_categorical_accuracy: 0.9580 - val_loss: 0.3234 - val_sparse_categorical_accuracy: 0.8488 - lr: 0.0010
# Epoch 74/500
# 90/90 [==============================] - 1s 5ms/step - loss: 0.1122 - sparse_categorical_accuracy: 0.9625 - val_loss: 0.2623 - val_sparse_categorical_accuracy: 0.8682 - lr: 0.0010
# Epoch 75/500
# 90/90 [==============================] - 0s 5ms/step - loss: 0.1174 - sparse_categorical_accuracy: 0.9576 - val_loss: 0.1506 - val_sparse_categorical_accuracy: 0.9515 - lr: 0.0010
# Epoch 76/500
# 90/90 [==============================] - 15s 164ms/step - loss: 0.1122 - sparse_categorical_accuracy: 0.9642 - val_loss: 0.4356 - val_sparse_categorical_accuracy: 0.7795 - lr: 0.0010
# Epoch 77/500
# 90/90 [==============================] - 0s 5ms/step - loss: 0.1278 - sparse_categorical_accuracy: 0.9535 - val_loss: 0.3828 - val_sparse_categorical_accuracy: 0.8252 - lr: 0.0010
# Epoch 78/500
# 90/90 [==============================] - 16s 175ms/step - loss: 0.1096 - sparse_categorical_accuracy: 0.9639 - val_loss: 0.9535 - val_sparse_categorical_accuracy: 0.7559 - lr: 0.0010
# Epoch 79/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.1118 - sparse_categorical_accuracy: 0.9653 - val_loss: 2.2269 - val_sparse_categorical_accuracy: 0.6838 - lr: 0.0010
# Epoch 80/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.1206 - sparse_categorical_accuracy: 0.9573 - val_loss: 0.3133 - val_sparse_categorical_accuracy: 0.8419 - lr: 0.0010
# Epoch 81/500
# 90/90 [==============================] - 12s 139ms/step - loss: 0.1117 - sparse_categorical_accuracy: 0.9663 - val_loss: 0.3656 - val_sparse_categorical_accuracy: 0.8308 - lr: 0.0010
# Epoch 82/500
# 90/90 [==============================] - 0s 3ms/step - loss: 0.1106 - sparse_categorical_accuracy: 0.9604 - val_loss: 0.8245 - val_sparse_categorical_accuracy: 0.7490 - lr: 0.0010
# Epoch 83/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.1069 - sparse_categorical_accuracy: 0.9660 - val_loss: 0.1287 - val_sparse_categorical_accuracy: 0.9556 - lr: 0.0010
# Epoch 84/500
# 90/90 [==============================] - 11s 122ms/step - loss: 0.1140 - sparse_categorical_accuracy: 0.9622 - val_loss: 0.1744 - val_sparse_categorical_accuracy: 0.9223 - lr: 0.0010
# Epoch 85/500
# 90/90 [==============================] - 0s 3ms/step - loss: 0.1136 - sparse_categorical_accuracy: 0.9639 - val_loss: 0.5787 - val_sparse_categorical_accuracy: 0.7961 - lr: 0.0010
# Epoch 86/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.1083 - sparse_categorical_accuracy: 0.9628 - val_loss: 0.2804 - val_sparse_categorical_accuracy: 0.8863 - lr: 0.0010
# Epoch 87/500
# 90/90 [==============================] - 15s 169ms/step - loss: 0.1046 - sparse_categorical_accuracy: 0.9642 - val_loss: 0.1206 - val_sparse_categorical_accuracy: 0.9556 - lr: 0.0010
# Epoch 88/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.1104 - sparse_categorical_accuracy: 0.9625 - val_loss: 0.2484 - val_sparse_categorical_accuracy: 0.8793 - lr: 0.0010
# Epoch 89/500
# 90/90 [==============================] - 0s 3ms/step - loss: 0.1054 - sparse_categorical_accuracy: 0.9663 - val_loss: 0.2776 - val_sparse_categorical_accuracy: 0.8599 - lr: 0.0010
# Epoch 90/500
# 90/90 [==============================] - 12s 138ms/step - loss: 0.1113 - sparse_categorical_accuracy: 0.9618 - val_loss: 0.2162 - val_sparse_categorical_accuracy: 0.8974 - lr: 0.0010
# Epoch 91/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.1036 - sparse_categorical_accuracy: 0.9646 - val_loss: 0.2544 - val_sparse_categorical_accuracy: 0.8655 - lr: 0.0010
# Epoch 92/500
# 90/90 [==============================] - 13s 151ms/step - loss: 0.1074 - sparse_categorical_accuracy: 0.9632 - val_loss: 0.4949 - val_sparse_categorical_accuracy: 0.7462 - lr: 0.0010
# Epoch 93/500
# 90/90 [==============================] - 16s 179ms/step - loss: 0.1082 - sparse_categorical_accuracy: 0.9615 - val_loss: 0.3124 - val_sparse_categorical_accuracy: 0.8350 - lr: 0.0010
# Epoch 94/500
# 90/90 [==============================] - 0s 5ms/step - loss: 0.1105 - sparse_categorical_accuracy: 0.9646 - val_loss: 0.1679 - val_sparse_categorical_accuracy: 0.9348 - lr: 0.0010
# Epoch 95/500
# 90/90 [==============================] - 17s 196ms/step - loss: 0.1047 - sparse_categorical_accuracy: 0.9625 - val_loss: 0.2094 - val_sparse_categorical_accuracy: 0.9140 - lr: 0.0010
# Epoch 96/500
# 90/90 [==============================] - 0s 5ms/step - loss: 0.1015 - sparse_categorical_accuracy: 0.9646 - val_loss: 0.1830 - val_sparse_categorical_accuracy: 0.9085 - lr: 0.0010
# Epoch 97/500
# 90/90 [==============================] - 16s 185ms/step - loss: 0.1085 - sparse_categorical_accuracy: 0.9639 - val_loss: 1.8385 - val_sparse_categorical_accuracy: 0.6463 - lr: 0.0010
# Epoch 98/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.1187 - sparse_categorical_accuracy: 0.9587 - val_loss: 0.6823 - val_sparse_categorical_accuracy: 0.7614 - lr: 0.0010
# Epoch 99/500
# 90/90 [==============================] - 16s 175ms/step - loss: 0.1118 - sparse_categorical_accuracy: 0.9639 - val_loss: 0.1083 - val_sparse_categorical_accuracy: 0.9542 - lr: 0.0010
# Epoch 100/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.1086 - sparse_categorical_accuracy: 0.9642 - val_loss: 0.0979 - val_sparse_categorical_accuracy: 0.9709 - lr: 0.0010
# Epoch 101/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.1038 - sparse_categorical_accuracy: 0.9632 - val_loss: 0.2089 - val_sparse_categorical_accuracy: 0.9029 - lr: 0.0010
# Epoch 102/500
# 90/90 [==============================] - 11s 129ms/step - loss: 0.1052 - sparse_categorical_accuracy: 0.9660 - val_loss: 0.2353 - val_sparse_categorical_accuracy: 0.8877 - lr: 0.0010
# Epoch 103/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.1000 - sparse_categorical_accuracy: 0.9681 - val_loss: 0.1419 - val_sparse_categorical_accuracy: 0.9528 - lr: 0.0010
# Epoch 104/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.1021 - sparse_categorical_accuracy: 0.9646 - val_loss: 0.8000 - val_sparse_categorical_accuracy: 0.7545 - lr: 0.0010
# Epoch 105/500
# 90/90 [==============================] - 12s 139ms/step - loss: 0.1005 - sparse_categorical_accuracy: 0.9667 - val_loss: 1.0260 - val_sparse_categorical_accuracy: 0.7434 - lr: 0.0010
# Epoch 106/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.1114 - sparse_categorical_accuracy: 0.9597 - val_loss: 4.1812 - val_sparse_categorical_accuracy: 0.6352 - lr: 0.0010
# Epoch 107/500
# 90/90 [==============================] - 14s 160ms/step - loss: 0.0916 - sparse_categorical_accuracy: 0.9694 - val_loss: 0.2172 - val_sparse_categorical_accuracy: 0.9085 - lr: 0.0010
# Epoch 108/500
# 90/90 [==============================] - 0s 5ms/step - loss: 0.1039 - sparse_categorical_accuracy: 0.9628 - val_loss: 1.8147 - val_sparse_categorical_accuracy: 0.7018 - lr: 0.0010
# Epoch 109/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.1058 - sparse_categorical_accuracy: 0.9604 - val_loss: 3.3397 - val_sparse_categorical_accuracy: 0.6533 - lr: 0.0010
# Epoch 110/500
# 90/90 [==============================] - 15s 170ms/step - loss: 0.0935 - sparse_categorical_accuracy: 0.9708 - val_loss: 0.0825 - val_sparse_categorical_accuracy: 0.9612 - lr: 0.0010
# Epoch 111/500
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0893 - sparse_categorical_accuracy: 0.9705 - val_loss: 3.4482 - val_sparse_categorical_accuracy: 0.6519 - lr: 0.0010
# Epoch 112/500
# 90/90 [==============================] - 12s 137ms/step - loss: 0.0958 - sparse_categorical_accuracy: 0.9663 - val_loss: 1.3205 - val_sparse_categorical_accuracy: 0.7254 - lr: 0.0010
# Epoch 113/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0928 - sparse_categorical_accuracy: 0.9698 - val_loss: 0.9113 - val_sparse_categorical_accuracy: 0.7531 - lr: 0.0010
# Epoch 114/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0914 - sparse_categorical_accuracy: 0.9681 - val_loss: 0.2109 - val_sparse_categorical_accuracy: 0.8904 - lr: 0.0010
# Epoch 115/500
# 90/90 [==============================] - 17s 189ms/step - loss: 0.0909 - sparse_categorical_accuracy: 0.9726 - val_loss: 0.1344 - val_sparse_categorical_accuracy: 0.9431 - lr: 0.0010
# Epoch 116/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0939 - sparse_categorical_accuracy: 0.9684 - val_loss: 0.3699 - val_sparse_categorical_accuracy: 0.8391 - lr: 0.0010
# Epoch 117/500
# 90/90 [==============================] - 14s 152ms/step - loss: 0.0962 - sparse_categorical_accuracy: 0.9681 - val_loss: 0.3040 - val_sparse_categorical_accuracy: 0.8516 - lr: 0.0010
# Epoch 118/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0910 - sparse_categorical_accuracy: 0.9653 - val_loss: 0.4717 - val_sparse_categorical_accuracy: 0.8239 - lr: 0.0010
# Epoch 119/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0938 - sparse_categorical_accuracy: 0.9663 - val_loss: 0.4129 - val_sparse_categorical_accuracy: 0.7975 - lr: 0.0010
# Epoch 120/500
# 90/90 [==============================] - 11s 129ms/step - loss: 0.1055 - sparse_categorical_accuracy: 0.9622 - val_loss: 1.1971 - val_sparse_categorical_accuracy: 0.5964 - lr: 0.0010
# Epoch 121/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0975 - sparse_categorical_accuracy: 0.9667 - val_loss: 0.7252 - val_sparse_categorical_accuracy: 0.7393 - lr: 0.0010
# Epoch 122/500
# 90/90 [==============================] - 13s 151ms/step - loss: 0.0910 - sparse_categorical_accuracy: 0.9698 - val_loss: 1.2426 - val_sparse_categorical_accuracy: 0.6796 - lr: 0.0010
# Epoch 123/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.1003 - sparse_categorical_accuracy: 0.9670 - val_loss: 0.3398 - val_sparse_categorical_accuracy: 0.8558 - lr: 0.0010
# Epoch 124/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0884 - sparse_categorical_accuracy: 0.9726 - val_loss: 0.1094 - val_sparse_categorical_accuracy: 0.9667 - lr: 0.0010
# Epoch 125/500
# 90/90 [==============================] - 10s 116ms/step - loss: 0.0892 - sparse_categorical_accuracy: 0.9708 - val_loss: 0.1252 - val_sparse_categorical_accuracy: 0.9528 - lr: 0.0010
# Epoch 126/500
# 90/90 [==============================] - 0s 5ms/step - loss: 0.1046 - sparse_categorical_accuracy: 0.9604 - val_loss: 0.6142 - val_sparse_categorical_accuracy: 0.7670 - lr: 0.0010
# Epoch 127/500
# 90/90 [==============================] - 18s 208ms/step - loss: 0.0972 - sparse_categorical_accuracy: 0.9639 - val_loss: 0.2932 - val_sparse_categorical_accuracy: 0.8724 - lr: 0.0010
# Epoch 128/500
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0919 - sparse_categorical_accuracy: 0.9684 - val_loss: 0.1801 - val_sparse_categorical_accuracy: 0.9126 - lr: 0.0010
# Epoch 129/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0833 - sparse_categorical_accuracy: 0.9715 - val_loss: 0.0941 - val_sparse_categorical_accuracy: 0.9723 - lr: 0.0010
# Epoch 130/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0938 - sparse_categorical_accuracy: 0.9691 - val_loss: 0.1487 - val_sparse_categorical_accuracy: 0.9279 - lr: 0.0010
# Epoch 131/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0810 - sparse_categorical_accuracy: 0.9722 - val_loss: 0.2804 - val_sparse_categorical_accuracy: 0.8724 - lr: 5.0000e-04
# Epoch 132/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0783 - sparse_categorical_accuracy: 0.9740 - val_loss: 0.0846 - val_sparse_categorical_accuracy: 0.9681 - lr: 5.0000e-04
# Epoch 133/500
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0785 - sparse_categorical_accuracy: 0.9726 - val_loss: 0.4335 - val_sparse_categorical_accuracy: 0.8405 - lr: 5.0000e-04
# Epoch 134/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0795 - sparse_categorical_accuracy: 0.9743 - val_loss: 0.0771 - val_sparse_categorical_accuracy: 0.9750 - lr: 5.0000e-04
# Epoch 135/500
# 90/90 [==============================] - 15s 6ms/step - loss: 0.0734 - sparse_categorical_accuracy: 0.9743 - val_loss: 0.1469 - val_sparse_categorical_accuracy: 0.9348 - lr: 5.0000e-04
# Epoch 136/500
# 90/90 [==============================] - 17s 188ms/step - loss: 0.0711 - sparse_categorical_accuracy: 0.9757 - val_loss: 0.0792 - val_sparse_categorical_accuracy: 0.9723 - lr: 5.0000e-04
# Epoch 137/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0692 - sparse_categorical_accuracy: 0.9757 - val_loss: 0.2206 - val_sparse_categorical_accuracy: 0.8904 - lr: 5.0000e-04
# Epoch 138/500
# 90/90 [==============================] - 11s 123ms/step - loss: 0.0725 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.0859 - val_sparse_categorical_accuracy: 0.9695 - lr: 5.0000e-04
# Epoch 139/500
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0780 - sparse_categorical_accuracy: 0.9743 - val_loss: 0.1149 - val_sparse_categorical_accuracy: 0.9473 - lr: 5.0000e-04
# Epoch 140/500
# 90/90 [==============================] - 29s 327ms/step - loss: 0.0772 - sparse_categorical_accuracy: 0.9753 - val_loss: 0.0672 - val_sparse_categorical_accuracy: 0.9792 - lr: 5.0000e-04
# Epoch 141/500
# 90/90 [==============================] - 13s 140ms/step - loss: 0.0771 - sparse_categorical_accuracy: 0.9743 - val_loss: 0.1007 - val_sparse_categorical_accuracy: 0.9584 - lr: 5.0000e-04
# Epoch 142/500
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0783 - sparse_categorical_accuracy: 0.9733 - val_loss: 0.1144 - val_sparse_categorical_accuracy: 0.9556 - lr: 5.0000e-04
# Epoch 143/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0697 - sparse_categorical_accuracy: 0.9760 - val_loss: 0.0741 - val_sparse_categorical_accuracy: 0.9750 - lr: 5.0000e-04
# Epoch 144/500
# 90/90 [==============================] - 11s 125ms/step - loss: 0.0728 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.0800 - val_sparse_categorical_accuracy: 0.9709 - lr: 5.0000e-04
# Epoch 145/500
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0678 - sparse_categorical_accuracy: 0.9795 - val_loss: 0.0724 - val_sparse_categorical_accuracy: 0.9778 - lr: 5.0000e-04
# Epoch 146/500
# 90/90 [==============================] - 14s 157ms/step - loss: 0.0732 - sparse_categorical_accuracy: 0.9760 - val_loss: 0.3785 - val_sparse_categorical_accuracy: 0.8405 - lr: 5.0000e-04
# Epoch 147/500
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0736 - sparse_categorical_accuracy: 0.9767 - val_loss: 0.1979 - val_sparse_categorical_accuracy: 0.9057 - lr: 5.0000e-04
# Epoch 148/500
# 90/90 [==============================] - 16s 181ms/step - loss: 0.0749 - sparse_categorical_accuracy: 0.9722 - val_loss: 0.0672 - val_sparse_categorical_accuracy: 0.9681 - lr: 5.0000e-04
# Epoch 149/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0784 - sparse_categorical_accuracy: 0.9719 - val_loss: 0.4892 - val_sparse_categorical_accuracy: 0.8336 - lr: 5.0000e-04
# Epoch 150/500
# 90/90 [==============================] - 15s 165ms/step - loss: 0.0701 - sparse_categorical_accuracy: 0.9750 - val_loss: 0.3351 - val_sparse_categorical_accuracy: 0.8710 - lr: 5.0000e-04
# Epoch 151/500
# 90/90 [==============================] - 15s 171ms/step - loss: 0.0736 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.1026 - val_sparse_categorical_accuracy: 0.9626 - lr: 5.0000e-04
# Epoch 152/500
# 90/90 [==============================] - 1s 7ms/step - loss: 0.0734 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.0818 - val_sparse_categorical_accuracy: 0.9736 - lr: 5.0000e-04
# Epoch 153/500
# 90/90 [==============================] - 62s 695ms/step - loss: 0.0707 - sparse_categorical_accuracy: 0.9788 - val_loss: 0.2378 - val_sparse_categorical_accuracy: 0.8960 - lr: 5.0000e-04
# Epoch 154/500
# 90/90 [==============================] - 118s 1s/step - loss: 0.0704 - sparse_categorical_accuracy: 0.9753 - val_loss: 0.1690 - val_sparse_categorical_accuracy: 0.9265 - lr: 5.0000e-04
# Epoch 155/500
# 90/90 [==============================] - 1s 7ms/step - loss: 0.0709 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.1093 - val_sparse_categorical_accuracy: 0.9570 - lr: 5.0000e-04
# Epoch 156/500
# 90/90 [==============================] - 19s 209ms/step - loss: 0.0772 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.1577 - val_sparse_categorical_accuracy: 0.9362 - lr: 5.0000e-04
# Epoch 157/500
# 90/90 [==============================] - 1s 7ms/step - loss: 0.0734 - sparse_categorical_accuracy: 0.9750 - val_loss: 0.0846 - val_sparse_categorical_accuracy: 0.9709 - lr: 5.0000e-04
# Epoch 158/500
# 90/90 [==============================] - 15s 169ms/step - loss: 0.0691 - sparse_categorical_accuracy: 0.9760 - val_loss: 0.0811 - val_sparse_categorical_accuracy: 0.9667 - lr: 5.0000e-04
# Epoch 159/500
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0648 - sparse_categorical_accuracy: 0.9778 - val_loss: 0.1702 - val_sparse_categorical_accuracy: 0.9279 - lr: 5.0000e-04
# Epoch 160/500
# 90/90 [==============================] - 18s 202ms/step - loss: 0.0726 - sparse_categorical_accuracy: 0.9747 - val_loss: 0.1090 - val_sparse_categorical_accuracy: 0.9542 - lr: 5.0000e-04
# Epoch 161/500
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0669 - sparse_categorical_accuracy: 0.9778 - val_loss: 0.0703 - val_sparse_categorical_accuracy: 0.9750 - lr: 2.5000e-04
# Epoch 162/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0695 - sparse_categorical_accuracy: 0.9785 - val_loss: 0.0818 - val_sparse_categorical_accuracy: 0.9695 - lr: 2.5000e-04
# Epoch 163/500
# 90/90 [==============================] - 14s 156ms/step - loss: 0.0654 - sparse_categorical_accuracy: 0.9802 - val_loss: 0.0880 - val_sparse_categorical_accuracy: 0.9736 - lr: 2.5000e-04
# Epoch 164/500
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0638 - sparse_categorical_accuracy: 0.9781 - val_loss: 0.0825 - val_sparse_categorical_accuracy: 0.9709 - lr: 2.5000e-04
# Epoch 165/500
# 90/90 [==============================] - 18s 203ms/step - loss: 0.0640 - sparse_categorical_accuracy: 0.9806 - val_loss: 0.0841 - val_sparse_categorical_accuracy: 0.9653 - lr: 2.5000e-04
# Epoch 166/500
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0652 - sparse_categorical_accuracy: 0.9760 - val_loss: 0.0898 - val_sparse_categorical_accuracy: 0.9709 - lr: 2.5000e-04
# Epoch 167/500
# 90/90 [==============================] - 11s 129ms/step - loss: 0.0686 - sparse_categorical_accuracy: 0.9767 - val_loss: 0.1020 - val_sparse_categorical_accuracy: 0.9653 - lr: 2.5000e-04
# Epoch 168/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0667 - sparse_categorical_accuracy: 0.9785 - val_loss: 0.0846 - val_sparse_categorical_accuracy: 0.9584 - lr: 2.5000e-04
# Epoch 169/500
# 90/90 [==============================] - 1s 7ms/step - loss: 0.0645 - sparse_categorical_accuracy: 0.9785 - val_loss: 0.0765 - val_sparse_categorical_accuracy: 0.9681 - lr: 2.5000e-04
# Epoch 170/500
# 90/90 [==============================] - 14s 156ms/step - loss: 0.0623 - sparse_categorical_accuracy: 0.9809 - val_loss: 0.1466 - val_sparse_categorical_accuracy: 0.9279 - lr: 2.5000e-04
# Epoch 171/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0618 - sparse_categorical_accuracy: 0.9785 - val_loss: 0.1721 - val_sparse_categorical_accuracy: 0.9154 - lr: 2.5000e-04
# Epoch 172/500
# 90/90 [==============================] - 12s 139ms/step - loss: 0.0626 - sparse_categorical_accuracy: 0.9826 - val_loss: 0.0709 - val_sparse_categorical_accuracy: 0.9778 - lr: 2.5000e-04
# Epoch 173/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0584 - sparse_categorical_accuracy: 0.9816 - val_loss: 0.0675 - val_sparse_categorical_accuracy: 0.9709 - lr: 2.5000e-04
# Epoch 174/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0641 - sparse_categorical_accuracy: 0.9799 - val_loss: 0.1317 - val_sparse_categorical_accuracy: 0.9390 - lr: 2.5000e-04
# Epoch 175/500
# 90/90 [==============================] - 14s 157ms/step - loss: 0.0614 - sparse_categorical_accuracy: 0.9819 - val_loss: 0.1432 - val_sparse_categorical_accuracy: 0.9376 - lr: 2.5000e-04
# Epoch 176/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0603 - sparse_categorical_accuracy: 0.9809 - val_loss: 0.0715 - val_sparse_categorical_accuracy: 0.9723 - lr: 2.5000e-04
# Epoch 177/500
# 90/90 [==============================] - 16s 178ms/step - loss: 0.0625 - sparse_categorical_accuracy: 0.9802 - val_loss: 0.0823 - val_sparse_categorical_accuracy: 0.9709 - lr: 2.5000e-04
# Epoch 178/500
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0628 - sparse_categorical_accuracy: 0.9792 - val_loss: 0.1169 - val_sparse_categorical_accuracy: 0.9528 - lr: 2.5000e-04
# Epoch 179/500
# 90/90 [==============================] - 15s 166ms/step - loss: 0.0628 - sparse_categorical_accuracy: 0.9774 - val_loss: 0.0877 - val_sparse_categorical_accuracy: 0.9653 - lr: 2.5000e-04
# Epoch 180/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0590 - sparse_categorical_accuracy: 0.9816 - val_loss: 0.0737 - val_sparse_categorical_accuracy: 0.9723 - lr: 2.5000e-04
# Epoch 181/500
# 90/90 [==============================] - 14s 162ms/step - loss: 0.0549 - sparse_categorical_accuracy: 0.9819 - val_loss: 0.0750 - val_sparse_categorical_accuracy: 0.9667 - lr: 1.2500e-04
# Epoch 182/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0592 - sparse_categorical_accuracy: 0.9840 - val_loss: 0.0814 - val_sparse_categorical_accuracy: 0.9653 - lr: 1.2500e-04
# Epoch 183/500
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0565 - sparse_categorical_accuracy: 0.9844 - val_loss: 0.0645 - val_sparse_categorical_accuracy: 0.9764 - lr: 1.2500e-04
# Epoch 184/500
# 90/90 [==============================] - 16s 179ms/step - loss: 0.0575 - sparse_categorical_accuracy: 0.9806 - val_loss: 0.0669 - val_sparse_categorical_accuracy: 0.9723 - lr: 1.2500e-04
# Epoch 185/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0521 - sparse_categorical_accuracy: 0.9844 - val_loss: 0.0764 - val_sparse_categorical_accuracy: 0.9764 - lr: 1.2500e-04
# Epoch 186/500
# 90/90 [==============================] - 12s 137ms/step - loss: 0.0550 - sparse_categorical_accuracy: 0.9837 - val_loss: 0.0672 - val_sparse_categorical_accuracy: 0.9764 - lr: 1.2500e-04
# Epoch 187/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0547 - sparse_categorical_accuracy: 0.9816 - val_loss: 0.0740 - val_sparse_categorical_accuracy: 0.9653 - lr: 1.2500e-04
# Epoch 188/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0560 - sparse_categorical_accuracy: 0.9830 - val_loss: 0.0666 - val_sparse_categorical_accuracy: 0.9750 - lr: 1.2500e-04
# Epoch 189/500
# 90/90 [==============================] - 32s 363ms/step - loss: 0.0568 - sparse_categorical_accuracy: 0.9809 - val_loss: 0.0742 - val_sparse_categorical_accuracy: 0.9736 - lr: 1.2500e-04
# Epoch 190/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0651 - sparse_categorical_accuracy: 0.9799 - val_loss: 0.1057 - val_sparse_categorical_accuracy: 0.9542 - lr: 1.2500e-04
# Epoch 191/500
# 90/90 [==============================] - 15s 163ms/step - loss: 0.0594 - sparse_categorical_accuracy: 0.9792 - val_loss: 0.0777 - val_sparse_categorical_accuracy: 0.9736 - lr: 1.2500e-04
# Epoch 192/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0597 - sparse_categorical_accuracy: 0.9826 - val_loss: 0.0699 - val_sparse_categorical_accuracy: 0.9778 - lr: 1.2500e-04
# Epoch 193/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0631 - sparse_categorical_accuracy: 0.9764 - val_loss: 0.0708 - val_sparse_categorical_accuracy: 0.9736 - lr: 1.2500e-04
# Epoch 194/500
# 90/90 [==============================] - 12s 138ms/step - loss: 0.0602 - sparse_categorical_accuracy: 0.9816 - val_loss: 0.0769 - val_sparse_categorical_accuracy: 0.9750 - lr: 1.2500e-04
# Epoch 195/500
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0530 - sparse_categorical_accuracy: 0.9823 - val_loss: 0.0675 - val_sparse_categorical_accuracy: 0.9764 - lr: 1.2500e-04
# Epoch 196/500
# 90/90 [==============================] - 16s 183ms/step - loss: 0.0559 - sparse_categorical_accuracy: 0.9823 - val_loss: 0.0719 - val_sparse_categorical_accuracy: 0.9709 - lr: 1.2500e-04
# Epoch 197/500
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0570 - sparse_categorical_accuracy: 0.9802 - val_loss: 0.0791 - val_sparse_categorical_accuracy: 0.9667 - lr: 1.2500e-04
# Epoch 198/500
# 90/90 [==============================] - 12s 131ms/step - loss: 0.0601 - sparse_categorical_accuracy: 0.9806 - val_loss: 0.0769 - val_sparse_categorical_accuracy: 0.9667 - lr: 1.2500e-04
# Epoch 199/500
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0562 - sparse_categorical_accuracy: 0.9809 - val_loss: 0.0940 - val_sparse_categorical_accuracy: 0.9570 - lr: 1.2500e-04
# Epoch 200/500
# 90/90 [==============================] - 10s 107ms/step - loss: 0.0538 - sparse_categorical_accuracy: 0.9833 - val_loss: 0.0865 - val_sparse_categorical_accuracy: 0.9626 - lr: 1.2500e-04
# Epoch 201/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0563 - sparse_categorical_accuracy: 0.9795 - val_loss: 0.0679 - val_sparse_categorical_accuracy: 0.9723 - lr: 1.2500e-04
# Epoch 202/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0539 - sparse_categorical_accuracy: 0.9816 - val_loss: 0.0693 - val_sparse_categorical_accuracy: 0.9792 - lr: 1.2500e-04
# Epoch 203/500
# 90/90 [==============================] - 10s 108ms/step - loss: 0.0562 - sparse_categorical_accuracy: 0.9844 - val_loss: 0.0660 - val_sparse_categorical_accuracy: 0.9792 - lr: 1.2500e-04
# Epoch 204/500
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0552 - sparse_categorical_accuracy: 0.9826 - val_loss: 0.0679 - val_sparse_categorical_accuracy: 0.9792 - lr: 1.0000e-04
# Epoch 205/500
# 90/90 [==============================] - 13s 141ms/step - loss: 0.0568 - sparse_categorical_accuracy: 0.9812 - val_loss: 0.0684 - val_sparse_categorical_accuracy: 0.9764 - lr: 1.0000e-04
# Epoch 206/500
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0540 - sparse_categorical_accuracy: 0.9851 - val_loss: 0.0687 - val_sparse_categorical_accuracy: 0.9792 - lr: 1.0000e-04
# Epoch 207/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0529 - sparse_categorical_accuracy: 0.9826 - val_loss: 0.0898 - val_sparse_categorical_accuracy: 0.9653 - lr: 1.0000e-04
# Epoch 208/500
# 90/90 [==============================] - 9s 101ms/step - loss: 0.0550 - sparse_categorical_accuracy: 0.9840 - val_loss: 0.0655 - val_sparse_categorical_accuracy: 0.9778 - lr: 1.0000e-04
# Epoch 209/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0566 - sparse_categorical_accuracy: 0.9826 - val_loss: 0.0900 - val_sparse_categorical_accuracy: 0.9709 - lr: 1.0000e-04
# Epoch 210/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0546 - sparse_categorical_accuracy: 0.9830 - val_loss: 0.0672 - val_sparse_categorical_accuracy: 0.9778 - lr: 1.0000e-04
# Epoch 211/500
# 90/90 [==============================] - 9s 106ms/step - loss: 0.0552 - sparse_categorical_accuracy: 0.9830 - val_loss: 0.0728 - val_sparse_categorical_accuracy: 0.9723 - lr: 1.0000e-04
# Epoch 212/500
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0559 - sparse_categorical_accuracy: 0.9812 - val_loss: 0.0731 - val_sparse_categorical_accuracy: 0.9764 - lr: 1.0000e-04
# Epoch 213/500
# 90/90 [==============================] - 10s 115ms/step - loss: 0.0588 - sparse_categorical_accuracy: 0.9802 - val_loss: 0.0701 - val_sparse_categorical_accuracy: 0.9778 - lr: 1.0000e-04
# Epoch 214/500
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0501 - sparse_categorical_accuracy: 0.9847 - val_loss: 0.0712 - val_sparse_categorical_accuracy: 0.9764 - lr: 1.0000e-04
# Epoch 215/500
# 90/90 [==============================] - 10s 118ms/step - loss: 0.0568 - sparse_categorical_accuracy: 0.9785 - val_loss: 0.0760 - val_sparse_categorical_accuracy: 0.9681 - lr: 1.0000e-04
# Epoch 216/500
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0539 - sparse_categorical_accuracy: 0.9812 - val_loss: 0.0657 - val_sparse_categorical_accuracy: 0.9778 - lr: 1.0000e-04
# Epoch 217/500
# 90/90 [==============================] - 10s 117ms/step - loss: 0.0563 - sparse_categorical_accuracy: 0.9819 - val_loss: 0.0923 - val_sparse_categorical_accuracy: 0.9667 - lr: 1.0000e-04
# Epoch 218/500
# 90/90 [==============================] - 1s 6ms/step - loss: 0.0540 - sparse_categorical_accuracy: 0.9806 - val_loss: 0.0646 - val_sparse_categorical_accuracy: 0.9778 - lr: 1.0000e-04
# Epoch 219/500
# 90/90 [==============================] - 11s 118ms/step - loss: 0.0551 - sparse_categorical_accuracy: 0.9823 - val_loss: 0.0665 - val_sparse_categorical_accuracy: 0.9778 - lr: 1.0000e-04
# Epoch 220/500
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0540 - sparse_categorical_accuracy: 0.9819 - val_loss: 0.0656 - val_sparse_categorical_accuracy: 0.9764 - lr: 1.0000e-04
# Epoch 221/500
# 90/90 [==============================] - 6s 70ms/step - loss: 0.0540 - sparse_categorical_accuracy: 0.9812 - val_loss: 0.0654 - val_sparse_categorical_accuracy: 0.9792 - lr: 1.0000e-04
# Epoch 222/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0521 - sparse_categorical_accuracy: 0.9854 - val_loss: 0.0648 - val_sparse_categorical_accuracy: 0.9792 - lr: 1.0000e-04
# Epoch 223/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0522 - sparse_categorical_accuracy: 0.9858 - val_loss: 0.0720 - val_sparse_categorical_accuracy: 0.9778 - lr: 1.0000e-04
# Epoch 224/500
# 90/90 [==============================] - 4s 39ms/step - loss: 0.0522 - sparse_categorical_accuracy: 0.9833 - val_loss: 0.0860 - val_sparse_categorical_accuracy: 0.9612 - lr: 1.0000e-04
# Epoch 225/500
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0530 - sparse_categorical_accuracy: 0.9826 - val_loss: 0.0637 - val_sparse_categorical_accuracy: 0.9736 - lr: 1.0000e-04
# Epoch 226/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0533 - sparse_categorical_accuracy: 0.9799 - val_loss: 0.0639 - val_sparse_categorical_accuracy: 0.9778 - lr: 1.0000e-04
# Epoch 227/500
# 90/90 [==============================] - 3s 37ms/step - loss: 0.0508 - sparse_categorical_accuracy: 0.9858 - val_loss: 0.0899 - val_sparse_categorical_accuracy: 0.9667 - lr: 1.0000e-04
# Epoch 228/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0534 - sparse_categorical_accuracy: 0.9840 - val_loss: 0.0660 - val_sparse_categorical_accuracy: 0.9764 - lr: 1.0000e-04
# Epoch 229/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0549 - sparse_categorical_accuracy: 0.9826 - val_loss: 0.0655 - val_sparse_categorical_accuracy: 0.9764 - lr: 1.0000e-04
# Epoch 230/500
# 90/90 [==============================] - 3s 38ms/step - loss: 0.0512 - sparse_categorical_accuracy: 0.9844 - val_loss: 0.0658 - val_sparse_categorical_accuracy: 0.9778 - lr: 1.0000e-04
# Epoch 231/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0515 - sparse_categorical_accuracy: 0.9830 - val_loss: 0.0713 - val_sparse_categorical_accuracy: 0.9778 - lr: 1.0000e-04
# Epoch 232/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0510 - sparse_categorical_accuracy: 0.9854 - val_loss: 0.0771 - val_sparse_categorical_accuracy: 0.9626 - lr: 1.0000e-04
# Epoch 233/500
# 90/90 [==============================] - 3s 36ms/step - loss: 0.0493 - sparse_categorical_accuracy: 0.9847 - val_loss: 0.1054 - val_sparse_categorical_accuracy: 0.9515 - lr: 1.0000e-04
# Epoch 234/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0509 - sparse_categorical_accuracy: 0.9854 - val_loss: 0.0666 - val_sparse_categorical_accuracy: 0.9792 - lr: 1.0000e-04
# Epoch 235/500
# 90/90 [==============================] - 0s 3ms/step - loss: 0.0551 - sparse_categorical_accuracy: 0.9861 - val_loss: 0.0688 - val_sparse_categorical_accuracy: 0.9709 - lr: 1.0000e-04
# Epoch 236/500
# 90/90 [==============================] - 3s 37ms/step - loss: 0.0521 - sparse_categorical_accuracy: 0.9847 - val_loss: 0.0654 - val_sparse_categorical_accuracy: 0.9750 - lr: 1.0000e-04
# Epoch 237/500
# 90/90 [==============================] - 0s 3ms/step - loss: 0.0531 - sparse_categorical_accuracy: 0.9823 - val_loss: 0.0666 - val_sparse_categorical_accuracy: 0.9792 - lr: 1.0000e-04
# Epoch 238/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0559 - sparse_categorical_accuracy: 0.9833 - val_loss: 0.0695 - val_sparse_categorical_accuracy: 0.9792 - lr: 1.0000e-04
# Epoch 239/500
# 90/90 [==============================] - 3s 36ms/step - loss: 0.0517 - sparse_categorical_accuracy: 0.9847 - val_loss: 0.0741 - val_sparse_categorical_accuracy: 0.9653 - lr: 1.0000e-04
# Epoch 240/500
# ...
# Epoch 277/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0476 - sparse_categorical_accuracy: 0.9837 - val_loss: 0.0653 - val_sparse_categorical_accuracy: 0.9792 - lr: 1.0000e-04
# Epoch 278/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0509 - sparse_categorical_accuracy: 0.9823 - val_loss: 0.0668 - val_sparse_categorical_accuracy: 0.9778 - lr: 1.0000e-04
# Epoch 279/500
# 90/90 [==============================] - 3s 37ms/step - loss: 0.0479 - sparse_categorical_accuracy: 0.9865 - val_loss: 0.0681 - val_sparse_categorical_accuracy: 0.9778 - lr: 1.0000e-04
# Epoch 280/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0490 - sparse_categorical_accuracy: 0.9840 - val_loss: 0.0655 - val_sparse_categorical_accuracy: 0.9764 - lr: 1.0000e-04
# Epoch 281/500
# 90/90 [==============================] - 0s 3ms/step - loss: 0.0497 - sparse_categorical_accuracy: 0.9826 - val_loss: 0.0873 - val_sparse_categorical_accuracy: 0.9639 - lr: 1.0000e-04
# Epoch 282/500
# 90/90 [==============================] - 3s 39ms/step - loss: 0.0500 - sparse_categorical_accuracy: 0.9830 - val_loss: 0.0642 - val_sparse_categorical_accuracy: 0.9792 - lr: 1.0000e-04
# Epoch 283/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0533 - sparse_categorical_accuracy: 0.9823 - val_loss: 0.0652 - val_sparse_categorical_accuracy: 0.9764 - lr: 1.0000e-04
# Epoch 284/500
# 90/90 [==============================] - 4s 44ms/step - loss: 0.0482 - sparse_categorical_accuracy: 0.9858 - val_loss: 0.0814 - val_sparse_categorical_accuracy: 0.9736 - lr: 1.0000e-04
# Epoch 285/500
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0456 - sparse_categorical_accuracy: 0.9847 - val_loss: 0.0695 - val_sparse_categorical_accuracy: 0.9681 - lr: 1.0000e-04
# Epoch 286/500
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0527 - sparse_categorical_accuracy: 0.9826 - val_loss: 0.0857 - val_sparse_categorical_accuracy: 0.9639 - lr: 1.0000e-04
# Epoch 287/500
# 90/90 [==============================] - 4s 40ms/step - loss: 0.0496 - sparse_categorical_accuracy: 0.9837 - val_loss: 0.0646 - val_sparse_categorical_accuracy: 0.9778 - lr: 1.0000e-04
# Epoch 288/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0452 - sparse_categorical_accuracy: 0.9882 - val_loss: 0.0681 - val_sparse_categorical_accuracy: 0.9806 - lr: 1.0000e-04
# Epoch 289/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0484 - sparse_categorical_accuracy: 0.9847 - val_loss: 0.0740 - val_sparse_categorical_accuracy: 0.9778 - lr: 1.0000e-04
# Epoch 290/500
# 90/90 [==============================] - 3s 36ms/step - loss: 0.0495 - sparse_categorical_accuracy: 0.9847 - val_loss: 0.0699 - val_sparse_categorical_accuracy: 0.9778 - lr: 1.0000e-04
# Epoch 291/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0463 - sparse_categorical_accuracy: 0.9865 - val_loss: 0.0739 - val_sparse_categorical_accuracy: 0.9764 - lr: 1.0000e-04
# Epoch 292/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0496 - sparse_categorical_accuracy: 0.9872 - val_loss: 0.0769 - val_sparse_categorical_accuracy: 0.9681 - lr: 1.0000e-04
# Epoch 293/500
# 90/90 [==============================] - 3s 38ms/step - loss: 0.0518 - sparse_categorical_accuracy: 0.9833 - val_loss: 0.0666 - val_sparse_categorical_accuracy: 0.9764 - lr: 1.0000e-04
# Epoch 294/500
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0501 - sparse_categorical_accuracy: 0.9840 - val_loss: 0.0636 - val_sparse_categorical_accuracy: 0.9792 - lr: 1.0000e-04
# Epoch 295/500
# 90/90 [==============================] - 5s 61ms/step - loss: 0.0485 - sparse_categorical_accuracy: 0.9868 - val_loss: 0.0660 - val_sparse_categorical_accuracy: 0.9764 - lr: 1.0000e-04
# Epoch 296/500
# 90/90 [==============================] - 1s 7ms/step - loss: 0.0471 - sparse_categorical_accuracy: 0.9861 - val_loss: 0.0875 - val_sparse_categorical_accuracy: 0.9584 - lr: 1.0000e-04
# Epoch 297/500
# 90/90 [==============================] - 5s 60ms/step - loss: 0.0462 - sparse_categorical_accuracy: 0.9837 - val_loss: 0.0641 - val_sparse_categorical_accuracy: 0.9778 - lr: 1.0000e-04
# Epoch 298/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0545 - sparse_categorical_accuracy: 0.9826 - val_loss: 0.0802 - val_sparse_categorical_accuracy: 0.9653 - lr: 1.0000e-04
# Epoch 299/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0457 - sparse_categorical_accuracy: 0.9844 - val_loss: 0.0689 - val_sparse_categorical_accuracy: 0.9709 - lr: 1.0000e-04
# Epoch 300/500
# 90/90 [==============================] - 4s 44ms/step - loss: 0.0485 - sparse_categorical_accuracy: 0.9875 - val_loss: 0.0653 - val_sparse_categorical_accuracy: 0.9778 - lr: 1.0000e-04
# Epoch 301/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0487 - sparse_categorical_accuracy: 0.9837 - val_loss: 0.0641 - val_sparse_categorical_accuracy: 0.9792 - lr: 1.0000e-04
# Epoch 302/500
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0502 - sparse_categorical_accuracy: 0.9847 - val_loss: 0.0684 - val_sparse_categorical_accuracy: 0.9778 - lr: 1.0000e-04
# Epoch 303/500
# 90/90 [==============================] - 4s 47ms/step - loss: 0.0477 - sparse_categorical_accuracy: 0.9851 - val_loss: 0.0672 - val_sparse_categorical_accuracy: 0.9764 - lr: 1.0000e-04
# Epoch 304/500
# 90/90 [==============================] - 0s 3ms/step - loss: 0.0468 - sparse_categorical_accuracy: 0.9854 - val_loss: 0.0684 - val_sparse_categorical_accuracy: 0.9736 - lr: 1.0000e-04
# Epoch 305/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0498 - sparse_categorical_accuracy: 0.9847 - val_loss: 0.0676 - val_sparse_categorical_accuracy: 0.9792 - lr: 1.0000e-04
# Epoch 306/500
# 90/90 [==============================] - 5s 53ms/step - loss: 0.0455 - sparse_categorical_accuracy: 0.9854 - val_loss: 0.0628 - val_sparse_categorical_accuracy: 0.9750 - lr: 1.0000e-04
# Epoch 307/500
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0463 - sparse_categorical_accuracy: 0.9861 - val_loss: 0.1063 - val_sparse_categorical_accuracy: 0.9528 - lr: 1.0000e-04
# Epoch 308/500
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0511 - sparse_categorical_accuracy: 0.9823 - val_loss: 0.0801 - val_sparse_categorical_accuracy: 0.9626 - lr: 1.0000e-04
# Epoch 309/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0489 - sparse_categorical_accuracy: 0.9847 - val_loss: 0.0637 - val_sparse_categorical_accuracy: 0.9736 - lr: 1.0000e-04
# Epoch 310/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0467 - sparse_categorical_accuracy: 0.9875 - val_loss: 0.0645 - val_sparse_categorical_accuracy: 0.9792 - lr: 1.0000e-04
# Epoch 311/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0474 - sparse_categorical_accuracy: 0.9844 - val_loss: 0.0725 - val_sparse_categorical_accuracy: 0.9792 - lr: 1.0000e-04
# Epoch 312/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0480 - sparse_categorical_accuracy: 0.9844 - val_loss: 0.0641 - val_sparse_categorical_accuracy: 0.9750 - lr: 1.0000e-04
# Epoch 313/500
# 90/90 [==============================] - 0s 3ms/step - loss: 0.0474 - sparse_categorical_accuracy: 0.9844 - val_loss: 0.0716 - val_sparse_categorical_accuracy: 0.9792 - lr: 1.0000e-04
# Epoch 314/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0508 - sparse_categorical_accuracy: 0.9847 - val_loss: 0.0797 - val_sparse_categorical_accuracy: 0.9695 - lr: 1.0000e-04
# Epoch 315/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0446 - sparse_categorical_accuracy: 0.9872 - val_loss: 0.0750 - val_sparse_categorical_accuracy: 0.9764 - lr: 1.0000e-04
# Epoch 316/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0435 - sparse_categorical_accuracy: 0.9865 - val_loss: 0.0805 - val_sparse_categorical_accuracy: 0.9723 - lr: 1.0000e-04
# Epoch 317/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0457 - sparse_categorical_accuracy: 0.9865 - val_loss: 0.0643 - val_sparse_categorical_accuracy: 0.9792 - lr: 1.0000e-04
# Epoch 318/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0484 - sparse_categorical_accuracy: 0.9837 - val_loss: 0.0715 - val_sparse_categorical_accuracy: 0.9806 - lr: 1.0000e-04
# Epoch 319/500
# 90/90 [==============================] - 0s 3ms/step - loss: 0.0485 - sparse_categorical_accuracy: 0.9844 - val_loss: 0.0652 - val_sparse_categorical_accuracy: 0.9736 - lr: 1.0000e-04
# Epoch 320/500
# 90/90 [==============================] - 0s 3ms/step - loss: 0.0451 - sparse_categorical_accuracy: 0.9865 - val_loss: 0.0713 - val_sparse_categorical_accuracy: 0.9709 - lr: 1.0000e-04
# Epoch 321/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0451 - sparse_categorical_accuracy: 0.9875 - val_loss: 0.0642 - val_sparse_categorical_accuracy: 0.9792 - lr: 1.0000e-04
# Epoch 322/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0471 - sparse_categorical_accuracy: 0.9837 - val_loss: 0.0693 - val_sparse_categorical_accuracy: 0.9750 - lr: 1.0000e-04
# Epoch 323/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0470 - sparse_categorical_accuracy: 0.9861 - val_loss: 0.0687 - val_sparse_categorical_accuracy: 0.9792 - lr: 1.0000e-04
# Epoch 324/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0481 - sparse_categorical_accuracy: 0.9865 - val_loss: 0.0737 - val_sparse_categorical_accuracy: 0.9750 - lr: 1.0000e-04
# Epoch 325/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0461 - sparse_categorical_accuracy: 0.9847 - val_loss: 0.0640 - val_sparse_categorical_accuracy: 0.9778 - lr: 1.0000e-04
# Epoch 326/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0421 - sparse_categorical_accuracy: 0.9899 - val_loss: 0.0738 - val_sparse_categorical_accuracy: 0.9778 - lr: 1.0000e-04
# Epoch 327/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0450 - sparse_categorical_accuracy: 0.9875 - val_loss: 0.0632 - val_sparse_categorical_accuracy: 0.9750 - lr: 1.0000e-04
# Epoch 328/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0472 - sparse_categorical_accuracy: 0.9854 - val_loss: 0.0927 - val_sparse_categorical_accuracy: 0.9584 - lr: 1.0000e-04
# Epoch 329/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0447 - sparse_categorical_accuracy: 0.9861 - val_loss: 0.0834 - val_sparse_categorical_accuracy: 0.9626 - lr: 1.0000e-04
# Epoch 330/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0431 - sparse_categorical_accuracy: 0.9868 - val_loss: 0.0681 - val_sparse_categorical_accuracy: 0.9736 - lr: 1.0000e-04
# Epoch 331/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0429 - sparse_categorical_accuracy: 0.9844 - val_loss: 0.0749 - val_sparse_categorical_accuracy: 0.9778 - lr: 1.0000e-04
# Epoch 332/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0455 - sparse_categorical_accuracy: 0.9872 - val_loss: 0.0705 - val_sparse_categorical_accuracy: 0.9792 - lr: 1.0000e-04
# Epoch 333/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0453 - sparse_categorical_accuracy: 0.9858 - val_loss: 0.0637 - val_sparse_categorical_accuracy: 0.9750 - lr: 1.0000e-04
# Epoch 334/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0432 - sparse_categorical_accuracy: 0.9878 - val_loss: 0.0649 - val_sparse_categorical_accuracy: 0.9778 - lr: 1.0000e-04
# Epoch 335/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0473 - sparse_categorical_accuracy: 0.9861 - val_loss: 0.0774 - val_sparse_categorical_accuracy: 0.9667 - lr: 1.0000e-04
# Epoch 336/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0496 - sparse_categorical_accuracy: 0.9858 - val_loss: 0.0662 - val_sparse_categorical_accuracy: 0.9736 - lr: 1.0000e-04
# Epoch 337/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0471 - sparse_categorical_accuracy: 0.9865 - val_loss: 0.0648 - val_sparse_categorical_accuracy: 0.9792 - lr: 1.0000e-04
# Epoch 338/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0510 - sparse_categorical_accuracy: 0.9819 - val_loss: 0.0883 - val_sparse_categorical_accuracy: 0.9612 - lr: 1.0000e-04
# Epoch 339/500
# 90/90 [==============================] - 0s 3ms/step - loss: 0.0460 - sparse_categorical_accuracy: 0.9854 - val_loss: 0.0726 - val_sparse_categorical_accuracy: 0.9778 - lr: 1.0000e-04
# Epoch 340/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0470 - sparse_categorical_accuracy: 0.9858 - val_loss: 0.0708 - val_sparse_categorical_accuracy: 0.9792 - lr: 1.0000e-04
# Epoch 341/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0484 - sparse_categorical_accuracy: 0.9833 - val_loss: 0.0641 - val_sparse_categorical_accuracy: 0.9778 - lr: 1.0000e-04
# Epoch 342/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0477 - sparse_categorical_accuracy: 0.9830 - val_loss: 0.0738 - val_sparse_categorical_accuracy: 0.9681 - lr: 1.0000e-04
# Epoch 343/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0488 - sparse_categorical_accuracy: 0.9833 - val_loss: 0.0819 - val_sparse_categorical_accuracy: 0.9626 - lr: 1.0000e-04
# Epoch 344/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0468 - sparse_categorical_accuracy: 0.9865 - val_loss: 0.0696 - val_sparse_categorical_accuracy: 0.9778 - lr: 1.0000e-04
# Epoch 345/500
# 90/90 [==============================] - 0s 5ms/step - loss: 0.0458 - sparse_categorical_accuracy: 0.9854 - val_loss: 0.0701 - val_sparse_categorical_accuracy: 0.9806 - lr: 1.0000e-04
# Epoch 346/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0468 - sparse_categorical_accuracy: 0.9861 - val_loss: 0.0680 - val_sparse_categorical_accuracy: 0.9778 - lr: 1.0000e-04
# Epoch 347/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0418 - sparse_categorical_accuracy: 0.9889 - val_loss: 0.0653 - val_sparse_categorical_accuracy: 0.9792 - lr: 1.0000e-04
# Epoch 348/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0485 - sparse_categorical_accuracy: 0.9865 - val_loss: 0.0729 - val_sparse_categorical_accuracy: 0.9709 - lr: 1.0000e-04
# Epoch 349/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0450 - sparse_categorical_accuracy: 0.9882 - val_loss: 0.1056 - val_sparse_categorical_accuracy: 0.9528 - lr: 1.0000e-04
# Epoch 350/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0431 - sparse_categorical_accuracy: 0.9875 - val_loss: 0.0635 - val_sparse_categorical_accuracy: 0.9736 - lr: 1.0000e-04
# Epoch 351/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0451 - sparse_categorical_accuracy: 0.9872 - val_loss: 0.0672 - val_sparse_categorical_accuracy: 0.9736 - lr: 1.0000e-04
# Epoch 352/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0486 - sparse_categorical_accuracy: 0.9861 - val_loss: 0.0634 - val_sparse_categorical_accuracy: 0.9764 - lr: 1.0000e-04
# Epoch 353/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0458 - sparse_categorical_accuracy: 0.9878 - val_loss: 0.0686 - val_sparse_categorical_accuracy: 0.9723 - lr: 1.0000e-04
# Epoch 354/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0459 - sparse_categorical_accuracy: 0.9847 - val_loss: 0.0640 - val_sparse_categorical_accuracy: 0.9806 - lr: 1.0000e-04
# Epoch 355/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0483 - sparse_categorical_accuracy: 0.9840 - val_loss: 0.0654 - val_sparse_categorical_accuracy: 0.9736 - lr: 1.0000e-04
# Epoch 356/500
# 90/90 [==============================] - 0s 4ms/step - loss: 0.0435 - sparse_categorical_accuracy: 0.9885 - val_loss: 0.0718 - val_sparse_categorical_accuracy: 0.9792 - lr: 1.0000e-04
# Epoch 356: early stopping

# %% [markdown]
# ## Evaluate model on test data

# %%
model = keras.models.load_model("best_model.keras")

test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test accuracy", test_acc)
print("Test loss", test_loss)
# Out:
# 42/42 [==============================] - 0s 7ms/step - loss: 0.0932 - sparse_categorical_accuracy: 0.9652
# Test accuracy 0.9651514887809753
# Test loss 0.09323529154062271

# %% [markdown]
# ## Plot the model's training and validation loss

# %%
metric = "sparse_categorical_accuracy"
plt.figure()
plt.plot(history.history[metric])
plt.plot(history.history["val_" + metric])
plt.title("model " + metric)
plt.ylabel(metric, fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")
plt.show()
plt.close()

# %% [markdown]
# We can see how the training accuracy reaches almost 0.95 after 100 epochs.
# However, by observing the validation accuracy we can see how the network still needs
# training until it reaches almost 0.97 for both the validation and the training accuracy
# after 200 epochs. Beyond the 200th epoch, if we continue on training, the validation
# accuracy will start decreasing while the training accuracy will continue on increasing:
# the model starts overfitting.
