# %% [markdown]
# # Timeseries anomaly detection using an Autoencoder
#
# **Author:** [pavithrasv](https://github.com/pavithrasv)<br>
# **Date created:** 2020/05/31<br>
# **Last modified:** 2020/05/31<br>
# **Description:** Detect anomalies in a timeseries using an Autoencoder.

# %% [markdown]
# ## Introduction
#
# This script demonstrates how you can use a reconstruction convolutional
# autoencoder model to detect anomalies in timeseries data.

# %% [markdown]
# ## Setup

# %%
import numpy as np
import pandas as pd
import keras
from keras import layers
from matplotlib import pyplot as plt
# Out:
# 2024-04-22 02:14:01.475876: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-04-22 02:14:01.496282: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-22 02:14:01.496301: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-22 02:14:01.496776: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-22 02:14:01.500403: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-22 02:14:01.897900: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Load the data
#
# We will use the [Numenta Anomaly Benchmark(NAB)](
# https://www.kaggle.com/boltzmannbrain/nab) dataset. It provides artificial
# timeseries data containing labeled anomalous periods of behavior. Data are
# ordered, timestamped, single-valued metrics.
#
# We will use the `art_daily_small_noise.csv` file for training and the
# `art_daily_jumpsup.csv` file for testing. The simplicity of this dataset
# allows us to demonstrate anomaly detection effectively.

# %%
master_url_root = "https://raw.githubusercontent.com/numenta/NAB/master/data/"

df_small_noise_url_suffix = "artificialNoAnomaly/art_daily_small_noise.csv"
df_small_noise_url = master_url_root + df_small_noise_url_suffix
df_small_noise = pd.read_csv(
    df_small_noise_url, parse_dates=True, index_col="timestamp"
)

df_daily_jumpsup_url_suffix = "artificialWithAnomaly/art_daily_jumpsup.csv"
df_daily_jumpsup_url = master_url_root + df_daily_jumpsup_url_suffix
df_daily_jumpsup = pd.read_csv(
    df_daily_jumpsup_url, parse_dates=True, index_col="timestamp"
)

# %% [markdown]
# ## Quick look at the data

# %%
print(df_small_noise.head())

print(df_daily_jumpsup.head())
# Out:
#                          value
# timestamp
# 2014-04-01 00:00:00  18.324919
# 2014-04-01 00:05:00  21.970327
# 2014-04-01 00:10:00  18.624806
# 2014-04-01 00:15:00  21.953684
# 2014-04-01 00:20:00  21.909120
#                          value
# timestamp
# 2014-04-01 00:00:00  19.761252
# 2014-04-01 00:05:00  20.500833
# 2014-04-01 00:10:00  19.961641
# 2014-04-01 00:15:00  21.490266
# 2014-04-01 00:20:00  20.187739

# %% [markdown]
# ## Visualize the data
# ### Timeseries data without anomalies
#
# We will use the following data for training.

# %%
fig, ax = plt.subplots()
df_small_noise.plot(legend=False, ax=ax)
plt.show()

# %% [markdown]
# ### Timeseries data with anomalies
#
# We will use the following data for testing and see if the sudden jump up in the
# data is detected as an anomaly.

# %%
fig, ax = plt.subplots()
df_daily_jumpsup.plot(legend=False, ax=ax)
plt.show()

# %% [markdown]
# ## Prepare training data
#
# Get data values from the training timeseries data file and normalize the
# `value` data. We have a `value` for every 5 mins for 14 days.
#
# -   24 * 60 / 5 = **288 timesteps per day**
# -   288 * 14 = **4032 data points** in total

# %%
# Normalize and save the mean and std we get,
# for normalizing test data.
training_mean = df_small_noise.mean()
training_std = df_small_noise.std()
df_training_value = (df_small_noise - training_mean) / training_std
print("Number of training samples:", len(df_training_value))
# Out:
# Number of training samples: 4032

# %% [markdown]
# ### Create sequences
# Create sequences combining `TIME_STEPS` contiguous data values from the
# training data.

# %%
TIME_STEPS = 288


# Generated training sequences for use in the model.
def create_sequences(values, time_steps=TIME_STEPS):
    output = []
    for i in range(len(values) - time_steps + 1):
        output.append(values[i : (i + time_steps)])
    return np.stack(output)


x_train = create_sequences(df_training_value.values)
print("Training input shape: ", x_train.shape)
# Out:
# Training input shape:  (3745, 288, 1)

# %% [markdown]
# ## Build a model
#
# We will build a convolutional reconstruction autoencoder model. The model will
# take input of shape `(batch_size, sequence_length, num_features)` and return
# output of the same shape. In this case, `sequence_length` is 288 and
# `num_features` is 1.

# %%
model = keras.Sequential(
    [
        layers.Input(shape=(x_train.shape[1], x_train.shape[2])),
        layers.Conv1D(
            filters=32,
            kernel_size=7,
            padding="same",
            strides=2,
            activation="relu",
        ),
        layers.Dropout(rate=0.2),
        layers.Conv1D(
            filters=16,
            kernel_size=7,
            padding="same",
            strides=2,
            activation="relu",
        ),
        layers.Conv1DTranspose(
            filters=16,
            kernel_size=7,
            padding="same",
            strides=2,
            activation="relu",
        ),
        layers.Dropout(rate=0.2),
        layers.Conv1DTranspose(
            filters=32,
            kernel_size=7,
            padding="same",
            strides=2,
            activation="relu",
        ),
        layers.Conv1DTranspose(filters=1, kernel_size=7, padding="same"),
    ]
)
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001), loss="mse")
model.summary()
# Out:
# 2024-04-22 02:14:05.629540: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-04-22 02:14:05.646810: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-04-22 02:14:05.646841: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-04-22 02:14:05.649081: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-04-22 02:14:05.649113: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-04-22 02:14:05.649128: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-04-22 02:14:05.741330: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-04-22 02:14:05.741368: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-04-22 02:14:05.741372: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2022] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2024-04-22 02:14:05.741392: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-04-22 02:14:05.741483: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9128 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070 Ti, pci bus id: 0000:01:00.0, compute capability: 8.9
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 model = keras.Sequential(
#       2     [
#       3         layers.Input(shape=(x_train.shape[1], x_train.shape[2])),
#       4         layers.Conv1D(
#       5             filters=32,
#       6             kernel_size=7,
#       7             padding="same",
#       8             strides=2,
#       9             activation="relu",
#      10         ),
#      11         layers.Dropout(rate=0.2),
#      12         layers.Conv1D(
#      13             filters=16,
#      14             kernel_size=7,
#      15             padding="same",
#      16             strides=2,
#      17             activation="relu",
#      18         ),
#      19         layers.Conv1DTranspose(
#      20             filters=16,
#      21             kernel_size=7,
#      22             padding="same",
#      23             strides=2,
#      24             activation="relu",
#      25         ),
#      26         layers.Dropout(rate=0.2),
#      27         layers.Conv1DTranspose(
#      28             filters=32,
#      29             kernel_size=7,
#      30             padding="same",
#      31             strides=2,
#      32             activation="relu",
#      33         ),
#      34         layers.Conv1DTranspose(filters=1, kernel_size=7, padding="same"),
#      35     ]
#      36 )
#      37 model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001), loss="mse")
#      38 model.summary()
#
# File ~/anaconda3/envs/p3.11tf2.16.1/lib/python3.11/site-packages/tensorflow/python/trackable/base.py:204, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     202 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     203 try:
# --> 204   result = method(self, *args, **kwargs)
#     205 finally:
#     206   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File ~/anaconda3/envs/p3.11tf2.16.1/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/p3.11tf2.16.1/lib/python3.11/site-packages/keras/src/engine/sequential.py:109, in Sequential.__init__(self, layers, name)
#     101 """Creates a `Sequential` model instance.
#     102
#     103 Args:
#     104   layers: Optional list of layers to add to the model.
#     105   name: Optional name for the model.
#     106 """
#     107 # Skip the init in FunctionalModel since model doesn't have input/output
#     108 # yet
# --> 109 super(functional.Functional, self).__init__(name=name, autocast=False)
#     110 base_layer.keras_api_gauge.get_cell("Sequential").set(True)
#     111 self.supports_masking = True
#
# File ~/anaconda3/envs/p3.11tf2.16.1/lib/python3.11/site-packages/tensorflow/python/trackable/base.py:204, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     202 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     203 try:
# --> 204   result = method(self, *args, **kwargs)
#     205 finally:
#     206   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File ~/anaconda3/envs/p3.11tf2.16.1/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/p3.11tf2.16.1/lib/python3.11/site-packages/keras/src/engine/training.py:328, in Model.__init__(self, *args, **kwargs)
#     324 self._autotune_steps_per_execution = False
#     326 self._layout_map = layout_map_lib.get_current_layout_map()
# --> 328 self._init_batch_counters()
#     329 self._base_model_initialized = True
#     331 # `jit_compile` starts off with None as default and gets overwritten by
#     332 # the value specified in `Model.compile`, and this is effective for
#     333 # `fit`, `evaluate`, and `predict`.
#
# File ~/anaconda3/envs/p3.11tf2.16.1/lib/python3.11/site-packages/tensorflow/python/trackable/base.py:204, in no_automatic_dependency_tracking.<locals>._method_wrapper(self, *args, **kwargs)
#     202 self._self_setattr_tracking = False  # pylint: disable=protected-access
#     203 try:
# --> 204   result = method(self, *args, **kwargs)
#     205 finally:
#     206   self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# File ~/anaconda3/envs/p3.11tf2.16.1/lib/python3.11/site-packages/keras/src/engine/training.py:367, in Model._init_batch_counters(self)
#     356 @tf.__internal__.tracking.no_automatic_dependency_tracking
#     357 def _init_batch_counters(self):
#     358     # Untracked Variables, used to keep track of mini-batches seen in `fit`,
#     359     # `evaluate`, and `predict`.
#     360     if not tf.inside_function():
#     361         # Creating variables inside tf.function is not allowed, hence
#     362         # these would otherwise prevent users from creating Keras layers
#     363         # inside tf.function.
#     364         # These variables are not connected to outputs so they have no
#     365         # effect on graph generation anyway.
# --> 367         self._train_counter = self._create_counter_variable(0)
#     368         self._test_counter = self._create_counter_variable(0)
#     369         self._predict_counter = self._create_counter_variable(0)
#
# File ~/anaconda3/envs/p3.11tf2.16.1/lib/python3.11/site-packages/keras/src/engine/training.py:347, in Model._create_counter_variable(self, init_value)
#     345 if self._layout_map is None:
#     346     agg = tf.VariableAggregation.ONLY_FIRST_REPLICA
# --> 347     return tf.Variable(init_value, dtype="int64", aggregation=agg)
#     348 else:
#     349     layout = dtensor_api.Layout.replicated(
#     350         mesh=self._layout_map.get_default_mesh(), rank=0
#     351     )
#
# File ~/anaconda3/envs/p3.11tf2.16.1/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/p3.11tf2.16.1/lib/python3.11/site-packages/tensorflow/python/ops/variables.py:195, in VariableMetaclass.__call__(cls, *args, **kwargs)
#     192 @traceback_utils.filter_traceback
#     193 def __call__(cls, *args, **kwargs):
#     194   if hasattr(cls, "_variable_call") and callable(cls._variable_call):
# --> 195     variable_call = cls._variable_call(*args, **kwargs)
#     196     if variable_call is not None:
#     197       return variable_call
#
# File ~/anaconda3/envs/p3.11tf2.16.1/lib/python3.11/site-packages/tensorflow/python/ops/variables.py:1227, in Variable._variable_call(cls, initial_value, trainable, validate_shape, caching_device, name, variable_def, dtype, import_scope, constraint, synchronization, aggregation, shape, experimental_enable_variable_lifting, **kwargs)
#    1225 if aggregation is None:
#    1226   aggregation = VariableAggregation.NONE
# -> 1227 return previous_getter(
#    1228     initial_value=initial_value,
#    1229     trainable=trainable,
#    1230     validate_shape=validate_shape,
#    1231     caching_device=caching_device,
#    1232     name=name,
#    1233     variable_def=variable_def,
#    1234     dtype=dtype,
#    1235     import_scope=import_scope,
#    1236     constraint=constraint,
#    1237     synchronization=synchronization,
#    1238     aggregation=aggregation,
#    1239     shape=shape,
#    1240     experimental_enable_variable_lifting=experimental_enable_variable_lifting,
#    1241     **kwargs
#    1242 )
#
# File ~/anaconda3/envs/p3.11tf2.16.1/lib/python3.11/site-packages/tensorflow/python/ops/variables.py:1220, in Variable._variable_call.<locals>.<lambda>(**kws)
#    1218 if cls is not Variable:
#    1219   return None
# -> 1220 previous_getter = lambda **kws: default_variable_creator_v2(None, **kws)
#    1221 for _, getter in ops.get_default_graph()._variable_creator_stack:  # pylint: disable=protected-access
#    1222   previous_getter = _make_getter(getter, previous_getter)
#
# File ~/anaconda3/envs/p3.11tf2.16.1/lib/python3.11/site-packages/tensorflow/python/ops/resource_variable_ops.py:357, in default_variable_creator_v2(next_creator, **kwargs)
#     353 shape = kwargs.get("shape", None)
#     354 experimental_enable_variable_lifting = kwargs.get(
#     355     "experimental_enable_variable_lifting", None)
# --> 357 return ResourceVariable(
#     358     initial_value=initial_value,
#     359     trainable=trainable,
#     360     validate_shape=validate_shape,
#     361     caching_device=caching_device,
#     362     name=name,
#     363     dtype=dtype,
#     364     constraint=constraint,
#     365     variable_def=variable_def,
#     366     import_scope=import_scope,
#     367     distribute_strategy=distribute_strategy,
#     368     synchronization=synchronization,
#     369     aggregation=aggregation,
#     370     shape=shape,
#     371     experimental_enable_variable_lifting=experimental_enable_variable_lifting,
#     372     )
#
# File ~/anaconda3/envs/p3.11tf2.16.1/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/p3.11tf2.16.1/lib/python3.11/site-packages/tensorflow/python/ops/variables.py:198, in VariableMetaclass.__call__(cls, *args, **kwargs)
#     196   if variable_call is not None:
#     197     return variable_call
# --> 198 return super(VariableMetaclass, cls).__call__(*args, **kwargs)
#
# File ~/anaconda3/envs/p3.11tf2.16.1/lib/python3.11/site-packages/tensorflow/python/ops/resource_variable_ops.py:1834, in ResourceVariable.__init__(self, initial_value, trainable, collections, validate_shape, caching_device, name, dtype, variable_def, import_scope, constraint, distribute_strategy, synchronization, aggregation, shape, handle, experimental_enable_variable_lifting)
#    1829   self._init_from_handle(trainable=trainable,
#    1830                          shape=shape,
#    1831                          dtype=dtype,
#    1832                          handle=handle)
#    1833 else:
# -> 1834   self._init_from_args(
#    1835       initial_value=initial_value,
#    1836       trainable=trainable,
#    1837       collections=collections,
#    1838       caching_device=caching_device,
#    1839       name=name,
#    1840       dtype=dtype,
#    1841       constraint=constraint,
#    1842       synchronization=synchronization,
#    1843       aggregation=aggregation,
#    1844       shape=shape,
#    1845       distribute_strategy=distribute_strategy,
#    1846       validate_shape=validate_shape,
#    1847       experimental_enable_variable_lifting=experimental_enable_variable_lifting,
#    1848       )
#
# File ~/anaconda3/envs/p3.11tf2.16.1/lib/python3.11/site-packages/tensorflow/python/ops/resource_variable_ops.py:2023, in ResourceVariable._init_from_args(self, initial_value, trainable, collections, caching_device, name, dtype, constraint, synchronization, aggregation, distribute_strategy, shape, validate_shape, experimental_enable_variable_lifting)
#    2021     self._update_uid = initial_value.checkpoint_position.restore_uid
#    2022     initial_value = initial_value.wrapped_value
# -> 2023   initial_value = ops.convert_to_tensor(
#    2024       initial_value, name="initial_value", dtype=dtype)
#    2025 if shape is not None:
#    2026   if not initial_value.shape.is_compatible_with(shape):
#
# File ~/anaconda3/envs/p3.11tf2.16.1/lib/python3.11/site-packages/tensorflow/python/profiler/trace.py:183, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     181   with Trace(trace_name, **trace_kwargs):
#     182     return func(*args, **kwargs)
# --> 183 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/p3.11tf2.16.1/lib/python3.11/site-packages/tensorflow/python/framework/ops.py:696, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#     694 # TODO(b/142518781): Fix all call-sites and remove redundant arg
#     695 preferred_dtype = preferred_dtype or dtype_hint
# --> 696 return tensor_conversion_registry.convert(
#     697     value, dtype, name, as_ref, preferred_dtype, accepted_result_types
#     698 )
#
# File ~/anaconda3/envs/p3.11tf2.16.1/lib/python3.11/site-packages/tensorflow/python/framework/tensor_conversion_registry.py:234, in convert(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     225       raise RuntimeError(
#     226           _add_error_prefix(
#     227               f"Conversion function {conversion_func!r} for type "
#    (...)
#     230               f"actual = {ret.dtype.base_dtype.name}",
#     231               name=name))
#     233 if ret is None:
# --> 234   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#     236 if ret is NotImplemented:
#     237   continue
#
# File ~/anaconda3/envs/p3.11tf2.16.1/lib/python3.11/site-packages/tensorflow/python/framework/constant_op.py:335, in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#     332 def _constant_tensor_conversion_function(v, dtype=None, name=None,
#     333                                          as_ref=False):
#     334   _ = as_ref
# --> 335   return constant(v, dtype=dtype, name=name)
#
# File ~/anaconda3/envs/p3.11tf2.16.1/lib/python3.11/site-packages/tensorflow/python/ops/weak_tensor_ops.py:142, in weak_tensor_binary_op_wrapper.<locals>.wrapper(*args, **kwargs)
#     140 def wrapper(*args, **kwargs):
#     141   if not ops.is_auto_dtype_conversion_enabled():
# --> 142     return op(*args, **kwargs)
#     143   bound_arguments = signature.bind(*args, **kwargs)
#     144   bound_arguments.apply_defaults()
#
# File ~/anaconda3/envs/p3.11tf2.16.1/lib/python3.11/site-packages/tensorflow/python/framework/constant_op.py:271, in constant(value, dtype, shape, name)
#     172 @tf_export("constant", v1=[])
#     173 def constant(
#     174     value, dtype=None, shape=None, name="Const"
#     175 ) -> Union[ops.Operation, ops._EagerTensorBase]:
#     176   """Creates a constant tensor from a tensor-like object.
#     177
#     178   Note: All eager `tf.Tensor` values are immutable (in contrast to
#    (...)
#     269     ValueError: if called on a symbolic tensor.
#     270   """
# --> 271   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     272                         allow_broadcast=True)
#
# File ~/anaconda3/envs/p3.11tf2.16.1/lib/python3.11/site-packages/tensorflow/python/framework/constant_op.py:284, in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     282     with trace.Trace("tf.constant"):
#     283       return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 284   return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     286 const_tensor = ops._create_graph_constant(  # pylint: disable=protected-access
#     287     value, dtype, shape, name, verify_shape, allow_broadcast
#     288 )
#     289 return const_tensor
#
# File ~/anaconda3/envs/p3.11tf2.16.1/lib/python3.11/site-packages/tensorflow/python/framework/constant_op.py:296, in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     292 def _constant_eager_impl(
#     293     ctx, value, dtype, shape, verify_shape
#     294 ) -> ops._EagerTensorBase:
#     295   """Creates a constant on the current device."""
# --> 296   t = convert_to_eager_tensor(value, ctx, dtype)
#     297   if shape is None:
#     298     return t
#
# File ~/anaconda3/envs/p3.11tf2.16.1/lib/python3.11/site-packages/tensorflow/python/framework/constant_op.py:103, in convert_to_eager_tensor(value, ctx, dtype)
#     101     dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     102 ctx.ensure_initialized()
# --> 103 return ops.EagerTensor(value, ctx.device_name, dtype)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Train the model
#
# Please note that we are using `x_train` as both the input and the target
# since this is a reconstruction model.

# %%
history = model.fit(
    x_train,
    x_train,
    epochs=50,
    batch_size=128,
    validation_split=0.1,
    callbacks=[
        keras.callbacks.EarlyStopping(monitor="val_loss", patience=5, mode="min")
    ],
)
# Out:
# Epoch 1/50
# 2024-04-21 10:22:42.574136: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8904
# 2024-04-21 10:22:43.923559: I external/local_xla/xla/service/service.cc:168] XLA service 0x7fe568a429e0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-04-21 10:22:43.923581: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4070 Ti, Compute Capability 8.9
# 2024-04-21 10:22:43.931388: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1713666163.975813    2302 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 27/27 [==============================] - 3s 26ms/step - loss: 0.4920 - val_loss: 0.0612
# Epoch 2/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0757 - val_loss: 0.0401
# Epoch 3/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0563 - val_loss: 0.0344
# Epoch 4/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0479 - val_loss: 0.0291
# Epoch 5/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0415 - val_loss: 0.0262
# Epoch 6/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0370 - val_loss: 0.0234
# Epoch 7/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0333 - val_loss: 0.0211
# Epoch 8/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0306 - val_loss: 0.0206
# Epoch 9/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0284 - val_loss: 0.0205
# Epoch 10/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0267 - val_loss: 0.0192
# Epoch 11/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0253 - val_loss: 0.0206
# Epoch 12/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0241 - val_loss: 0.0209
# Epoch 13/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.0230 - val_loss: 0.0206
# Epoch 14/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0222 - val_loss: 0.0218
# Epoch 15/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.0213 - val_loss: 0.0225

# %% [markdown]
# Let's plot training and validation loss to see how the training went.

# %%
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.legend()
plt.show()

# %% [markdown]
# ## Detecting anomalies
#
# We will detect anomalies by determining how well our model can reconstruct
# the input data.
#
#
# 1.   Find MAE loss on training samples.
# 2.   Find max MAE loss value. This is the worst our model has performed trying
# to reconstruct a sample. We will make this the `threshold` for anomaly
# detection.
# 3.   If the reconstruction loss for a sample is greater than this `threshold`
# value then we can infer that the model is seeing a pattern that it isn't
# familiar with. We will label this sample as an `anomaly`.

# %%
# Get train MAE loss.
x_train_pred = model.predict(x_train)
train_mae_loss = np.mean(np.abs(x_train_pred - x_train), axis=1)

plt.hist(train_mae_loss, bins=50)
plt.xlabel("Train MAE loss")
plt.ylabel("No of samples")
plt.show()

# Get reconstruction loss threshold.
threshold = np.max(train_mae_loss)
print("Reconstruction error threshold: ", threshold)
# Out:
# 118/118 [==============================] - 0s 2ms/step
# Reconstruction error threshold:  0.12827461301517426

# %% [markdown]
# ### Compare recontruction
#
# Just for fun, let's see how our model has recontructed the first sample.
# This is the 288 timesteps from day 1 of our training dataset.

# %%
# Checking how the first sequence is learnt
plt.plot(x_train[0])
plt.plot(x_train_pred[0])
plt.show()

# %% [markdown]
# ### Prepare test data

# %%
df_test_value = (df_daily_jumpsup - training_mean) / training_std
fig, ax = plt.subplots()
df_test_value.plot(legend=False, ax=ax)
plt.show()

# Create sequences from test values.
x_test = create_sequences(df_test_value.values)
print("Test input shape: ", x_test.shape)

# Get test MAE loss.
x_test_pred = model.predict(x_test)
test_mae_loss = np.mean(np.abs(x_test_pred - x_test), axis=1)
test_mae_loss = test_mae_loss.reshape((-1))

plt.hist(test_mae_loss, bins=50)
plt.xlabel("test MAE loss")
plt.ylabel("No of samples")
plt.show()

# Detect all the samples which are anomalies.
anomalies = test_mae_loss > threshold
print("Number of anomaly samples: ", np.sum(anomalies))
print("Indices of anomaly samples: ", np.where(anomalies))
# Out:
# Test input shape:  (3745, 288, 1)
# 118/118 [==============================] - 0s 1ms/step
# Number of anomaly samples:  404
# Indices of anomaly samples:  (array([ 786,  787,  788,  794, 1650, 1651, 1652, 1654, 1658, 2516, 2522,
#        2702, 2703, 2704, 2705, 2706, 2707, 2708, 2709, 2710, 2711, 2712,
#        2713, 2714, 2715, 2716, 2717, 2718, 2719, 2720, 2721, 2722, 2723,
#        2724, 2725, 2726, 2727, 2728, 2729, 2730, 2731, 2732, 2733, 2734,
#        2735, 2736, 2737, 2738, 2739, 2740, 2741, 2742, 2743, 2744, 2745,
#        2746, 2747, 2748, 2749, 2750, 2751, 2752, 2753, 2754, 2755, 2756,
#        2757, 2758, 2759, 2760, 2761, 2762, 2763, 2764, 2765, 2766, 2767,
#        2768, 2769, 2770, 2771, 2772, 2773, 2774, 2775, 2776, 2777, 2778,
#        2779, 2780, 2781, 2782, 2783, 2784, 2785, 2786, 2787, 2788, 2789,
#        2790, 2791, 2792, 2793, 2794, 2795, 2796, 2797, 2798, 2799, 2800,
#        2801, 2802, 2803, 2804, 2805, 2806, 2807, 2808, 2809, 2810, 2811,
#        2812, 2813, 2814, 2815, 2816, 2817, 2818, 2819, 2820, 2821, 2822,
#        2823, 2824, 2825, 2826, 2827, 2828, 2829, 2830, 2831, 2832, 2833,
#        2834, 2835, 2836, 2837, 2838, 2839, 2840, 2841, 2842, 2843, 2844,
#        2845, 2846, 2847, 2848, 2849, 2850, 2851, 2852, 2853, 2854, 2855,
#        2856, 2857, 2858, 2859, 2860, 2861, 2862, 2863, 2864, 2865, 2866,
#        2867, 2868, 2869, 2870, 2871, 2872, 2873, 2874, 2875, 2876, 2877,
#        2878, 2879, 2880, 2881, 2882, 2883, 2884, 2885, 2886, 2887, 2888,
#        2889, 2890, 2891, 2892, 2893, 2894, 2895, 2896, 2897, 2898, 2899,
#        2900, 2901, 2902, 2903, 2904, 2905, 2906, 2907, 2908, 2909, 2910,
#        2911, 2912, 2913, 2914, 2915, 2916, 2917, 2918, 2919, 2920, 2921,
#        2922, 2923, 2924, 2925, 2926, 2927, 2928, 2929, 2930, 2931, 2932,
#        2933, 2934, 2935, 2936, 2937, 2938, 2939, 2940, 2941, 2942, 2943,
#        2944, 2945, 2946, 2947, 2948, 2949, 2950, 2951, 2952, 2953, 2954,
#        2955, 2956, 2957, 2958, 2959, 2960, 2961, 2962, 2963, 2964, 2965,
#        2966, 2967, 2968, 2969, 2970, 2971, 2972, 2973, 2974, 2975, 2976,
#        2977, 2978, 2979, 2980, 2981, 2982, 2983, 2984, 2985, 2986, 2987,
#        2988, 2989, 2990, 2991, 2992, 2993, 2994, 2995, 2996, 2997, 2998,
#        2999, 3000, 3001, 3002, 3003, 3004, 3005, 3006, 3007, 3008, 3009,
#        3010, 3011, 3012, 3013, 3014, 3015, 3016, 3017, 3018, 3019, 3020,
#        3021, 3022, 3023, 3024, 3025, 3026, 3027, 3028, 3029, 3030, 3031,
#        3032, 3033, 3034, 3035, 3036, 3037, 3038, 3039, 3040, 3041, 3042,
#        3043, 3044, 3045, 3046, 3047, 3048, 3049, 3050, 3051, 3052, 3053,
#        3054, 3055, 3056, 3057, 3058, 3059, 3060, 3061, 3062, 3063, 3064,
#        3065, 3066, 3067, 3068, 3069, 3070, 3071, 3072, 3073, 3074, 3075,
#        3076, 3077, 3078, 3079, 3080, 3081, 3082, 3083, 3084, 3085, 3086,
#        3087, 3088, 3089, 3090, 3091, 3092, 3093, 3094]),)

# %% [markdown]
# ## Plot anomalies
#
# We now know the samples of the data which are anomalies. With this, we will
# find the corresponding `timestamps` from the original test data. We will be
# using the following method to do that:
#
# Let's say time_steps = 3 and we have 10 training values. Our `x_train` will
# look like this:
#
# - 0, 1, 2
# - 1, 2, 3
# - 2, 3, 4
# - 3, 4, 5
# - 4, 5, 6
# - 5, 6, 7
# - 6, 7, 8
# - 7, 8, 9
#
# All except the initial and the final time_steps-1 data values, will appear in
# `time_steps` number of samples. So, if we know that the samples
# [(3, 4, 5), (4, 5, 6), (5, 6, 7)] are anomalies, we can say that the data point
# 5 is an anomaly.

# %%
# data i is an anomaly if samples [(i - timesteps + 1) to (i)] are anomalies
anomalous_data_indices = []
for data_idx in range(TIME_STEPS - 1, len(df_test_value) - TIME_STEPS + 1):
    if np.all(anomalies[data_idx - TIME_STEPS + 1 : data_idx]):
        anomalous_data_indices.append(data_idx)

# %% [markdown]
# Let's overlay the anomalies on the original test data plot.

# %%
df_subset = df_daily_jumpsup.iloc[anomalous_data_indices]
fig, ax = plt.subplots()
df_daily_jumpsup.plot(legend=False, ax=ax)
df_subset.plot(legend=False, ax=ax, color="r")
plt.show()
